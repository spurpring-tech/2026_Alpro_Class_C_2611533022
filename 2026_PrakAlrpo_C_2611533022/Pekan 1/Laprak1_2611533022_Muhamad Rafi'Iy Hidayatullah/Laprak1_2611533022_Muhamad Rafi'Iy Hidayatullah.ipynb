# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“JUDUL MODUL PRAKTIKUM”**
#
# **Disusun Oleh :**
#
# **Muhamad Rafi'Iy Hidayatullah**
#
# **2611533022**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly sukmadira**
#
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Algoritma dan Pemrograman yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan Pengenalan Python VsCode dan koneksi github.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep pengenalan VsCode dan koneksi github pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Tuliskan latar belakang topik praktikum di sini: Untuk mulai mengenal dan memahami cara penggunaan Python, VsCode, dan GitHub untuk proses perkuliahan kedepannya.
#
# ## 1.2 Tujuan
# 1. Mengenal dasar - dasar bahasa pemograman python.
# 2. Memahami penggunaan VS CODE sebagai aplikasi untuk menulis dan menjalankan program.
# 3. Mengetahui cara menghubungkan dan menggunakan GitHub untuk menyimpan dan menggunalkan proyek.
#
# ## 1.3 Manfaat
# 1. Membantu meningkatkan pemahaman tentang dasar-dasar pemrograman.
# 2. Memudahkan proses pembuatan dan pengembangan program menggunakan VS Code.
# 3. Memudahlkan penyimpanan, pengelolaan, dan pembagian proyek melalui GitHub.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Mengenal dasar - dasar bahasa pemograman python.\
#     Python merupakan salah satu bahasa pemrograman yang banyak digunakan karena memiliki sintaks yang sederhana dan mudah dipahami. Dalam pembelajaran dasar, pengguna dapat mengenal cara menulis kode, menggunakan variabel, tipe data, serta membuat program sederhana. Python dapat digunakan dalam berbagai bidang, seperti pengembangan aplikasi, pengolahan data, dan kecerdasan buatan.
#
# 2. Memahami penggunaan VS CODE sebagai aplikasi untuk menulis dan menjalankan program.\
#     Memahami Penggunaan Visual Studio Code (VS Code) Visual Studio Code atau VS Code merupakan aplikasi yang digunakan untuk menulis dan mengedit kode program. VS Code menyediakan berbagai fitur yang dapat memudahkan pengguna dalam membuat program, seperti penulisan kode yang lebih terstruktur, ekstensi, dan terminal. Dengan menggunakan VsCode, proses pembuatan dan menjalankan program kode python lebih mudah
#
# 3. Mengetahui cara menghubungkan dan menggunakan GitHub untuk menyimpan dan menggunalkan proyek.\
#     Mengetahui Cara Menghubungkan dan Menggunakan GitHub GitHub merupakan platform yang digunakan untuk menyimpan dan mengelola proyek pemrograman secara online. GitHub memungkinkan pengguna lebih aman dan terorganisir.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "NamaKelas_NIM"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Tulis/tempel kode program di sini.
# Catatan: jika bahasa aslinya Java/C/dst, kode tetap bisa ditulis apa adanya
# di dalam sel ini sebagai referensi teks (tidak harus dieksekusi di Python),
# atau gunakan magic %%writefile untuk menuliskannya ke file .java lalu
# dijalankan lewat perintah shell (lihat file tutorial terpisah).
# Program Pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 pratikum alpro
"""
print ("Hello World")
print ()
print ("Departemen Informatika")
print ("Universitas Andalas")
print ("/ \\ // \\\\ /// \\\\\\")
print ("program ini " + "dibuat oleh a\\n" + "Muhamad Rafi'Iy Hidayatullah dan 2611533022")
# Out:
# Hello World
#
# Departemen Informatika
# Universitas Andalas
# / \ // \\ /// \\\
# program ini dibuat oleh a\nMuhamad Rafi'Iy Hidayatullah dan 2611533022

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk memberi kutipan komentar
# 2. Bagian kedua berfungsi untuk mencetak kata string "Hello World"
# 3. Bagian ketiga berfungsi untuk memberi baris kosong, memberi jarak antar baris karakter
# 4. Bagian keempat berfungsi untuk mencerak kata string "Departremen Informatika"
# 5. Bagian kelima berfungsi untuk mencerak kata string "Universitas Andalas"
# 6. Bagian keenam berfungsi untuk mencerak kata string "/ \\ // \\\\ /// \\\\\\"
# 7. Bagian ketujuh berfungsi untuk mencerak kata string "program ini " + "dibuat oleh a\\n" + "Muhamad Rafi'Iy Hidayatullah dan 2611533022"

# %% [markdown]
# ---
# # BAB II
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python merupakan bahasa pemrograman yang mudah dipelajari dan digunakan untuk membuat berbagai program. Dalam proses pemrograman, VsCode berfungsi sebagai aplikasi yang membantu pengguna dalam menulis, mengedit, dan menjalankan kode program.
#
#
# Dalam konteks pemrograman, GitHub dimanfaatkan sebagai platform untuk menyimpan, mengelola, dan membagikan proyek secara online, sehingga proses pengembangan program menjadi lebih terorganisir dan memudahkan pengguna dalam mengelola perubahan pada kode.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, "Python Documentation," https://docs.python.org/3/
#
# [2] Microsoft "Visual Studio Code Documentation." https://code.visualstudio.com/docs
#
# [3] GitHub, "GitHub Documentation," https://docs.github.com/
